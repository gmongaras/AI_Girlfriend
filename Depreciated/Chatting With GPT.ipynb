# %%
# Packages
# !pip install --upgrade openai
# !pip install openai[embeddings]
# Out:
# ...
#      --------------------------------------- 15.2/15.2 MB 38.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 148.2/148.2 kB 4.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 242.1/242.1 kB ? eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=444e39226fe26eb1e3f0411f7ced3c7db5c6a3aa3141df8ee647f1df05a84b46
#   Stored in directory: c:\users\gabri\appdata\local\pip\cache\wheels\f8\e0\3d\9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built sklearn
# ...

# %%
import openai
import requests

# %%
# Open AI Key
openai.api_key = "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"

# %%
# Get the models
# models = list(requests.get(url = "https://api.openai.com/v1/models", headers = {'Authorization':f'BEARER {openai.api_key}'}).json().values())[1]
models = openai.Model

# %%
models["data"].list()["data"][0]
# Out:
# <Model model id=babbage at 0x2a780e524a0> JSON: {
#   "created": 1649358449,
#   "id": "babbage",
#   "object": "model",
#   "owned_by": "openai",
#   "parent": null,
#   "permission": [
#     {
#       "allow_create_engine": false,
#       "allow_fine_tuning": false,
#       "allow_logprobs": true,
#       "allow_sampling": true,
#       "allow_search_indices": false,
#       "allow_view": true,
#       "created": 1669085501,
#       "group": null,
#       "id": "modelperm-49FUp5v084tBB49tC4z8LPH5",
#       "is_blocking": false,
#       "object": "model_permission",
#       "organization": "*"
#     }
#   ],
#   "root": "babbage"
# }

# %%
# List the models
for model in models["data"].list()["data"]:
    print(model["id"])
for model in models["data"].list()["data"]:
    print(model)
# Out:
# babbage
# ada
# davinci
# text-embedding-ada-002
# babbage-code-search-code
# text-similarity-babbage-001
# text-davinci-002
# text-davinci-001
# curie-instruct-beta
# babbage-code-search-text
# babbage-similarity
# curie-search-query
# code-search-babbage-text-001
# code-cushman-001
# code-search-babbage-code-001
# text-ada-001
# code-davinci-002
# text-similarity-ada-001
# text-davinci-insert-002
# ada-code-search-code
# ada-similarity
# code-search-ada-text-001
# text-search-ada-query-001
# text-curie-001
# text-davinci-edit-001
# davinci-search-document
# ada-code-search-text
# text-search-ada-doc-001
# code-davinci-edit-001
# davinci-instruct-beta
# text-babbage-001
# text-similarity-curie-001
# code-search-ada-code-001
# ada-search-query
# text-search-davinci-query-001
# curie-similarity
# davinci-search-query
# text-davinci-insert-001
# babbage-search-document
# ada-search-document
# curie
# text-search-babbage-doc-001
# text-search-curie-doc-001
# text-search-curie-query-001
# ...

# %%
# Practice API request
#https://beta.openai.com/docs/api-reference/introduction?lang=python
text = "I want you to chat with me like an anime waifu.\n"
output = openai.Completion.create(
  model="text-davinci-002",
  prompt=text,
  max_tokens=200,
  temperature=0
)

# %%
output["choices"][0]["text"]
# Out:
# '\nHey there! Thank you for spending some time with me! I hope we can get to know each other better!'
